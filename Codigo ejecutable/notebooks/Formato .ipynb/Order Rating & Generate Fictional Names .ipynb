# %% [markdown]
# ### Valoraciones ordenadas de mayor a menor para cada usuario
# Este notebook calcula y almacena de en un fichero externo una tabla con las valoraciones de los usuarios ordenadas, para cada uno de ellos de mayor a menor puntuación. Esta tabla es utilizada por el sistema para saber en qué películas fijarse para recomendar a un determinado usuarios y es actualizada en dicho sistema cuando un asuario agrega una nueva valoración.
#
# Además, en el notebook se realiza un mapeo entre los identificadores de usuario y diferentes nombres generados con la librería "names", que permite en la conversación usar un usuario con muchas valoraciones en el sistema y recibir recomendaciones de calidad (sin tener que añadir muchas valoraciones nosotros a un nuevo usuario para empezar a comprobar la calidad del sistema). Por ejemplo, si un ID de usuario con 100 valoraciones se mapea a "Albert Russell", si en una conversación con el sistema le decimos que nos llamamos Albert Russell, se basará en esas 100 valoraciones para recomendarnos contenido (además de las que podamos añadirle adicionalmente).

# %% [markdown]
# Importamos las librerías necesarias

# %%
import numpy as np
import pandas as pd
import names
import pickle

# %% [markdown]
# Cargamos el dataset de valoraciones quedándonos sólo con las 3 columnas que nos interesan

# %%
userRatings = pd.read_csv("ratings.csv")[['userId', 'rating', 'movieId']]
userRatings
# Out:
#           userId  rating  movieId
# 0              1     1.0      110
# 1              1     4.5      147
# 2              1     5.0      858
# 3              1     5.0     1221
# 4              1     5.0     1246
# ...          ...     ...      ...
# 26024284  270896     5.0    58559
# 26024285  270896     5.0    60069
# 26024286  270896     4.5    63082
# 26024287  270896     4.5    64957
# 26024288  270896     2.0    71878
#
# [26024289 rows x 3 columns]

# %% [markdown]
# Ordenamos el Dataframe primero por la clave del identificador de usuario y luego por la puntuación (en orden descendente). De esta forma tendremos para cada usuario ordenadas sus valoraciones de mayor a menor. almacenamos los datos en el fichero externo "ratings_ordered.csv"

# %%
userRatingsOrdered = userRatings.sort_values(by=['userId', 'rating'], ascending=False)[:50000]
userRatingsOrdered.to_csv("ratings_ordered.csv")

# %% [markdown]
# Cargamos el fichero que acabamos de crear y mostramos el dataset para comprobar que es correcto

# %%
userRatingsOrdered = pd.read_csv("ratings_ordered.csv")
userRatingsOrdered
# Out:
#        Unnamed: 0  userId  rating  movieId
# 0        26024034  270896     5.0       32
# 1        26024037  270896     5.0       47
# 2        26024038  270896     5.0       50
# 3        26024040  270896     5.0      110
# 4        26024041  270896     5.0      111
# ...           ...     ...     ...      ...
# 49995    25974290  270365     5.0      329
# 49996    25974292  270365     5.0      349
# 49997    25974293  270365     5.0      380
# 49998    25974294  270365     5.0      434
# 49999    25974295  270365     5.0      457
#
# [50000 rows x 4 columns]

# %% [markdown]
# Mostramos el número de usuarios únicos con valoraciones que tenemos

# %%
usersIds = userRatingsOrdered["userId"].unique()
print("Usuario únicos con valoraciones", len(usersIds))
# Out:
# Usuario únicos con valoraciones 532

# %% [markdown]
# Construimos un diccionario que tenga como claves tantos nombres (generados con la biblioteca names) como usuarios diferentes hay en el sistema, y como valores los IDs de estos. Es decir, que mapee nombres de usuario ficticios a IDs de usuario.

# %%
nameIDTable = {}
for userId in usersIds:
    nameIDTable[names.get_full_name()] = userId
nameIDTable
# Out:
# {'Charles Allen': 270896,
#  'Juan House': 270895,
#  'Nelly Alegre': 270894,
#  'Melissa Dyer': 270893,
#  'Mary Sharp': 270892,
#  'Peter Potter': 270891,
#  'Gloria Brown': 270890,
#  'Michael Thomas': 270889,
#  'Jason Glass': 270888,
#  'Theresa Lowry': 270887,
#  'Barbara Martinez': 270886,
#  'Tony Franklin': 270885,
#  'Dorothy Reynolds': 270884,
#  'Spencer Lutwin': 270883,
#  'Matthew Bras': 270882,
#  'Melva Bryant': 270881,
#  'Leonard Chadwick': 270880,
#  'Joan Hensley': 270879,
#  'Patty Alcala': 270878,
#  'Jason West': 270877,
#  'Jennifer Jackson': 270876,
#  'Colleen Slayton': 270875,
#  'Pauline Mckee': 270874,
#  'Jayson Peduto': 270873,
#  'Dorthea Barner': 270872,
#  'Alberta Warren': 270871,
#  'Jeffrey Dicamillo': 270870,
#  'Carlos Joiner': 270869,
#  'Eugene Carr': 270868,
#  'William Hullihen': 270867,
#  'Jason Stewart': 270866,
#  'William Smith': 270865,
#  'Katy Lee': 270864,
#  'Mildred Cooper': 270863,
#  'Michelle Uziel': 270862,
#  'Rosalind Blackmon': 270861,
#  'Kathy Caple': 270860,
#  'Leonard Green': 270859,
#  'Joe Noakes': 270858,
#  'Gladys Johnson': 270857,
#  'Diego Carlson': 270856,
#  'Omar Bookwalter': 270855,
#  'Francisco Shirley': 270854,
#  'Melissa Fraga': 270853,
#  'Brandon Matthews': 270852,
#  'Kurtis Apodaca': 270851,
#  'Joyce Austin': 270850,
#  'John Shuler': 270849,
#  'Pamela Brown': 270848,
#  'Susan Mason': 270847,
#  'Joshua Patrick': 270846,
#  'Branden White': 270845,
#  'Kelly Cyr': 270844,
#  'Matthew Siu': 270843,
#  'Janet Seaberry': 270842,
#  'Eva Fruge': 270841,
#  'Thomas Scott': 270840,
#  'James Mcentyre': 270839,
#  'Raymond Pullen': 270838,
#  'William Taylor': 270837,
#  'Rachel Dunigan': 270836,
#  'Evelyn Colucci': 270835,
#  'Cody Becker': 270834,
#  'Laura Nunez': 270833,
#  'Theresa Bowers': 270832,
#  'Diane Robert': 270831,
#  'Stephnie Ruiz': 270830,
#  'Irene Patterson': 270829,
#  'Bradford Francis': 270828,
#  'Michelle Flatter': 270827,
#  'James Koehn': 270826,
#  'Sanjuanita Davis': 270825,
#  'Leann Bordley': 270824,
#  'Kenneth Garrett': 270823,
#  'Alberta Middleton': 270822,
#  'Becky Jourdan': 270821,
#  'Leo Stinnett': 270820,
#  'Scott Clasen': 270819,
#  'Anne Monson': 270818,
#  'Kim Evans': 270817,
#  'Anna Allen': 270816,
#  'Eva Toney': 270815,
#  'Patricia Emmons': 270814,
#  'Lisa Ly': 270813,
#  'Peggy Kelly': 270812,
#  'Sylvia Beauchamp': 270811,
#  'Kevin Zurawski': 270810,
#  'Douglas Caldwell': 270809,
#  'Vanessa Cullens': 270808,
#  'Brenda Henry': 270807,
#  'Felicia Wright': 270806,
#  'Bette Williamson': 270805,
#  'Jody Brill': 270804,
#  'Joseph Mckee': 270803,
#  'Isabel Fish': 270802,
#  'George Potter': 270801,
#  'Terry Constantini': 270800,
#  'Melissa Rustad': 270799,
#  'Doris Delgado': 270798,
#  'Stacy Wright': 270797,
#  'Vernon Johnson': 270796,
#  'Joel Nieves': 270795,
#  'Otto Eldred': 270794,
#  'John Hunt': 270793,
#  'Astrid Collins': 270792,
#  'John Clark': 270791,
#  'Michael Salazar': 270790,
#  'Pennie Ortega': 270789,
#  'Joyce Kwan': 270788,
#  'Gail Mcgray': 270787,
#  'Robert Schmidt': 270786,
#  'Joseph Mekee': 270785,
#  'Ricky Shipp': 270784,
#  'Thomas Howard': 270783,
#  'Lorraine Mehta': 270782,
#  'Bessie Davidson': 270781,
#  'Adele Douglas': 270780,
#  'Stephen Beaumont': 270779,
#  'Derek Ryan': 270778,
#  'Patricia Lamb': 270777,
#  'Richard Williams': 270776,
#  'Randi Dykeman': 270775,
#  'Joseph Wells': 270774,
#  'Amanda Adams': 270773,
#  'Robert Andreason': 270772,
#  'John Fears': 270771,
#  'Agnes Obiesie': 270770,
#  'Louise Manrriquez': 270769,
#  'Luther Villalobos': 270768,
#  'Melissa Houston': 270767,
#  'Beth Osborne': 270766,
#  'Lenore Bastarache': 270765,
#  'Geralyn Villarreal': 270764,
#  'Scott Socia': 270763,
#  'William Mayes': 270762,
#  'Nadine Gonzalez': 270761,
#  'Walter Hayes': 270760,
#  'Truman Clouthier': 270759,
#  'Christy Clark': 270758,
#  'Alan Martinez': 270757,
#  'Jennifer Wells': 270756,
#  'Drucilla Bobbitt': 270755,
#  'Lucy Griffith': 270754,
#  'Gloria Munoz': 270753,
#  'Anna Flaherty': 270752,
#  'Francis Bobo': 270751,
#  'Vincent Ramirez': 270750,
#  'Nicole Sandy': 270749,
#  'Diane Jackson': 270748,
#  'Margaret Maranda': 270747,
#  'Tyler Riley': 270746,
#  'Ethan Aldrich': 270745,
#  'Marjorie Lazo': 270744,
#  'Wayne Adams': 270743,
#  'Paul Belmont': 270742,
#  'Fred Crowder': 270741,
#  'Ty Davidson': 270740,
#  'Marcia Price': 270739,
#  'Darlene Kirchoff': 270738,
#  'Theo Wheeler': 270737,
#  'Tina Lanier': 270736,
#  'Andrea Morales': 270735,
#  'Hannah Wilson': 270734,
#  'Lisa Petrulis': 270733,
#  'Lasandra Johnson': 270732,
#  'Gregory Cutler': 270731,
#  'Gerald Milone': 270730,
#  'Jack Edmisten': 270729,
#  'Elizabeth Wilson': 270728,
#  'Cindy Nagle': 270727,
#  'William Leven': 270726,
#  'Louis Palacio': 270725,
#  'John Evans': 270724,
#  'Mary Soria': 270723,
#  'Jodi Marks': 270722,
#  'Isabel Young': 270721,
#  'Carrie Gaunt': 270720,
#  'Jeffrey Fitch': 270719,
#  'Marlyn Coates': 270718,
#  'Alfredo Omersa': 270717,
#  'Edward Jensen': 270716,
#  'Lou Harman': 270715,
#  'Lottie Ayon': 270714,
#  'Michael Mclean': 270713,
#  'Mark Land': 270712,
#  'Terry Harms': 270711,
#  'Lisa Schaffer': 270710,
#  'Vicente Kane': 270709,
#  'Hermina Gibson': 270708,
#  'Duncan Johnson': 270707,
#  'Bob Mondragon': 270706,
#  'Thomas Morales': 270705,
#  'Jacob Bradford': 270704,
#  'Mary Pratt': 270703,
#  'Russell Hulsey': 270702,
#  'Pat Jury': 270701,
#  'Alice Pawlicki': 270700,
#  'Joseph Roberts': 270699,
#  'Harvey Sudbeck': 270698,
#  'Mark Badger': 270697,
#  'Terrence Cosselman': 270696,
#  'William Patterson': 270695,
#  'Lisa Nooner': 270694,
#  'Linda Bolden': 270693,
#  'Mary Rose': 270692,
#  'Mildred Levinson': 270691,
#  'Shirley Moran': 270690,
#  'Bert Klein': 270689,
#  'Maria Moreno': 270688,
#  'Gerald Foster': 270687,
#  'Catherine Clark': 270686,
#  'Regina Gross': 270685,
#  'Wayne Shook': 270684,
#  'Wesley Cardin': 270683,
#  'Roy Millspaugh': 270682,
#  'Ramiro Alvarez': 270681,
#  'Albert Mccall': 270680,
#  'Jackie Mott': 270679,
#  'Barb Earl': 270678,
#  'Thomas Thomas': 270677,
#  'Cheryl Rivera': 270676,
#  'Theodore Pero': 270675,
#  'Christina Jackson': 270674,
#  'Brigitte Witt': 270673,
#  'Kenneth Rosa': 270672,
#  'Melinda Degenfelder': 270671,
#  'Ma Goss': 270670,
#  'Marilyn Rhudy': 270669,
#  'Joseph Higgins': 270668,
#  'Barbara Baugh': 270667,
#  'Clay Duckworth': 270666,
#  'Brandon Rasmussen': 270665,
#  'Joel White': 270664,
#  'Susan Rangel': 270663,
#  'Amanda Jeffcoat': 270662,
#  'Esther Simpson': 270661,
#  'Eleanor Alcorn': 270660,
#  'Denise Halley': 270659,
#  'Harold Mayhew': 270658,
#  'Carmel Cummings': 270657,
#  'Kerrie Mitchell': 270656,
#  'John Brooks': 270655,
#  'Tyrone Siegfried': 270654,
#  'Donna Bradley': 270653,
#  'Robert Ruff': 270652,
#  'Sherry Belcher': 270651,
#  'Phyllis Philbrook': 270650,
#  'Mary Laughlin': 270649,
#  'Jerry Torres': 270648,
#  'David Jacobs': 270647,
#  'Mary Boutte': 270646,
#  'Elizabeth West': 270645,
#  'Christine Burroughs': 270644,
#  'Barbara Lopez': 270643,
#  'William Huggins': 270642,
#  'Charles Lewis': 270641,
#  'Steve Walker': 270640,
#  'Robert Lara': 270639,
#  'Karin Ragin': 270638,
#  'Valarie Hung': 270637,
#  'Crystal Strubbe': 270636,
#  'Catherine Bell': 270635,
#  'Joe Green': 270634,
#  'Carlos Zarella': 270633,
#  'Harold Scott': 270632,
#  'Billy Hall': 270631,
#  'John Rubio': 270630,
#  'Marilyn Rich': 270629,
#  'Thomas Mack': 270628,
#  'Ester Williams': 270627,
#  'Georgia Scott': 270626,
#  'Guadalupe Marchitto': 270625,
#  'Irene Soares': 270624,
#  'Marla Bishop': 270623,
#  'Angel Martin': 270622,
#  'Erika Saxon': 270621,
#  'Kelvin Huff': 270620,
#  'Nancy Booth': 270619,
#  'Eric Reed': 270618,
#  'Philip Raven': 270617,
#  'Richard Sparrow': 270616,
#  'Lily Santiago': 270615,
#  'Scott Walters': 270614,
#  'Kellie Jordan': 270613,
#  'Richard Plagmann': 270612,
#  'Ronald Brian': 270611,
#  'Janet Preston': 270610,
#  'Thomas Daniel': 270609,
#  'Joseph Castillo': 270608,
#  'Derek Hicks': 270607,
#  'Tyrell See': 270606,
#  'Michael Dufrene': 270605,
#  'Brian Blackburn': 270604,
#  'Beverly Box': 270603,
#  'Samuel Najera': 270602,
#  'Denise Zinn': 270601,
#  'Robert Brown': 270600,
#  'Robert Burleson': 270599,
#  'William Ball': 270598,
#  'Gertrude Smith': 270597,
#  'Gene Vilkama': 270596,
#  'Mary Kam': 270595,
#  'Latrice Deleon': 270594,
#  'Mark Swayzer': 270593,
#  'Gloria Bradshaw': 270592,
#  'Richard Neal': 270591,
#  'Tommy Liles': 270590,
#  'Rochelle Abdullah': 270589,
#  'Gregory Allen': 270588,
#  'Juanita Stewart': 270587,
#  'Patrick Vassallo': 270586,
#  'Bobby Harris': 270585,
#  'Lois Draeger': 270584,
#  'Clayton Mccoy': 270583,
#  'Donte Lindeland': 270582,
#  'Emily Long': 270581,
#  'Rose Culp': 270580,
#  'Candice Hanks': 270579,
#  'Michael Weigand': 270578,
#  'Robert Duncan': 270577,
#  'Jeffrey Carr': 270576,
#  'Leticia Lapointe': 270575,
#  'Patsy Mermis': 270574,
#  'Richard Rosa': 270573,
#  'Gregory Byrd': 270572,
#  'Helen Pace': 270571,
#  'Peter Caffee': 270570,
#  'Mary Avila': 270569,
#  'William Altman': 270568,
#  'Eddie Guthrie': 270567,
#  'Karen Naylor': 270566,
#  'Mary Townsley': 270565,
#  'Jesse Eddy': 270564,
#  'Cortney Stevens': 270563,
#  'Emma Bass': 270562,
#  'Eugenia Hampton': 270561,
#  'Kennith Smith': 270560,
#  'Tyrone Hicks': 270559,
#  'Kimberly Howell': 270558,
#  'Carrie Remo': 270557,
#  'Rebecca Guiles': 270556,
#  'Christina Burns': 270555,
#  'Cheryl Bynum': 270554,
#  'Douglas Williams': 270553,
#  'Terry Cameron': 270552,
#  'Jesse Thomas': 270551,
#  'Gregory Stump': 270550,
#  'Juan Cannella': 270549,
#  'Pete Kratz': 270548,
#  'William Jackson': 270547,
#  'Clarence Boyd': 270546,
#  'Bernice Whitney': 270545,
#  'Bobby Kimball': 270544,
#  'Blanca Roach': 270543,
#  'Vivian Fair': 270542,
#  'Josephine Mohseni': 270541,
#  'John Kelly': 270540,
#  'Sonia Boyer': 270539,
#  'Walter Goin': 270538,
#  'Brendan Camacho': 270537,
#  'Karen Kraft': 270536,
#  'Morris Steward': 270535,
#  'Martha Williams': 270534,
#  'Michelle Brock': 270533,
#  'Alfred Reeves': 270532,
#  'Betty Mcgill': 270531,
#  'Henry Davis': 270530,
#  'Victoria Pare': 270529,
#  'Edward Schroeder': 270528,
#  'Donna Seidlitz': 270527,
#  'Norman Lykes': 270526,
#  'Jose Thiessen': 270525,
#  'Rhonda Miller': 270524,
#  'Theodore Gutierrez': 270523,
#  'Nina Lerner': 270522,
#  'Doris Oconnor': 270521,
#  'Deborah Greer': 270520,
#  'Doris Schoppert': 270519,
#  'David Owens': 270518,
#  'Amy Eng': 270517,
#  'Melissa Segal': 270516,
#  'Justin Jones': 270515,
#  'Bill Zmolek': 270514,
#  'William Cadena': 270513,
#  'Annie Autrey': 270512,
#  'William Dolson': 270511,
#  'Dana Heard': 270510,
#  'William Gibb': 270509,
#  'Matthew Prather': 270508,
#  'Dwight Yates': 270507,
#  'Michael Heninger': 270506,
#  'Miranda Luna': 270505,
#  'Ignacio Goebel': 270504,
#  'Tamara Quintana': 270503,
#  'Jesse Gray': 270502,
#  'Kimberly Berry': 270501,
#  'Richard Schindler': 270500,
#  'Delmar Winkler': 270499,
#  'Jennifer Talley': 270498,
#  'Harriet Zepeda': 270497,
#  'Lesley Slagle': 270496,
#  'Arlene Neyhart': 270495,
#  'Ida Ramirez': 270494,
#  'Jordan Beckel': 270493,
#  'Andrew Roper': 270492,
#  'Mary Jacobs': 270491,
#  'Patricia Davis': 270490,
#  'Nathan Knesek': 270489,
#  'Howard Crump': 270488,
#  'Lisette Rebello': 270487,
#  'Janet Ford': 270486,
#  'Nathan Brock': 270485,
#  'Thomas Lowry': 270484,
#  'George Peters': 270483,
#  'Lindsey Brinkman': 270482,
#  'Alicia Schermerhorn': 270481,
#  'Silvia Price': 270480,
#  'Dan Booth': 270479,
#  'Jennifer Greene': 270478,
#  'Christopher Roy': 270477,
#  'Ashley Graham': 270476,
#  'Joel Velasquez': 270475,
#  'Roger Reasner': 270474,
#  'Audrey Grullon': 270473,
#  'Harry Coleman': 270472,
#  'Annette Hughes': 270471,
#  'Darren Silas': 270470,
#  'Alice Jones': 270469,
#  'Lillian Metters': 270468,
#  'Corazon Decaro': 270467,
#  'Jared Raisley': 270466,
#  'Christopher Rodriguez': 270465,
#  'Leonard Matthews': 270464,
#  'Lorna Holland': 270463,
#  'Amelia Anderson': 270462,
#  'Michael Avila': 270461,
#  'Joseph Wright': 270460,
#  'Mary Williams': 270459,
#  'Rita Clements': 270458,
#  'Don Keith': 270457,
#  'May Ralston': 270456,
#  'Patrick Becknell': 270455,
#  'Michelle Jones': 270454,
#  'Essie Travis': 270453,
#  'Jose Shultz': 270452,
#  'Karma Mccray': 270451,
#  'Marilyn Ovellette': 270450,
#  'Manuel Bass': 270449,
#  'Daniel Gray': 270448,
#  'Kathryn Anderson': 270447,
#  'Jeffery Greene': 270446,
#  'Graham Dupre': 270445,
#  'Susan Priester': 270444,
#  'Susan Tewell': 270443,
#  'Patricia Estler': 270442,
#  'Robert Colson': 270441,
#  'Daniel Bird': 270440,
#  'Tammy Barkley': 270439,
#  'Johnathan Golliday': 270438,
#  'Carl Edmons': 270437,
#  'Katherine Harris': 270436,
#  'Dorothy Cuellar': 270435,
#  'Gabriele Simon': 270434,
#  'Edwin Black': 270433,
#  'Charles Chester': 270432,
#  'Maurice Tahon': 270431,
#  'Martha Garrett': 270430,
#  'Leroy Takahashi': 270429,
#  'James Bernal': 270428,
#  'Carlos Wren': 270427,
#  'Dedra Parker': 270426,
#  'Robert Nichols': 270425,
#  'Jerome Smiley': 270424,
#  'Priscilla Lino': 270423,
#  'Carmen Brown': 270422,
#  'Lawrence Reed': 270421,
#  'Frank Cannaday': 270420,
#  'Samuel Smiechowski': 270419,
#  'Mary Loera': 270418,
#  'Markus Horace': 270417,
#  'Jeremy Crigler': 270416,
#  'Willie Heuer': 270415,
#  'Angela Richards': 270414,
#  'Geraldine Stone': 270413,
#  'Kendra Turner': 270412,
#  'Alton Rios': 270411,
#  'Bruce Harper': 270410,
#  'Norman Warren': 270409,
#  'Glendora Allen': 270408,
#  'Jane Cross': 270407,
#  'Mario Jackson': 270406,
#  'Victor Gonzalez': 270405,
#  'Lena Nelson': 270404,
#  'Betty Jones': 270403,
#  'Jeanette Holland': 270402,
#  'Jaclyn Wilson': 270401,
#  'Donald Carr': 270400,
#  'Lynn Grimes': 270399,
#  'Omar Marshall': 270398,
#  'Janelle Woodard': 270397,
#  'Particia Key': 270396,
#  'Linda Castellana': 270395,
#  'Erma Sims': 270394,
#  'Ervin Snyder': 270393,
#  'Debra Carp': 270392,
#  'Wilson Truax': 270391,
#  'Ernest Rhodes': 270390,
#  'Antonio Rogers': 270389,
#  'Joseph Skeen': 270388,
#  'Susan Rush': 270387,
#  'Johnny Rice': 270386,
#  'Lisa Hayes': 270385,
#  'Nona Madaras': 270384,
#  'Maria Deltoro': 270383,
#  'Eddie Smith': 270382,
#  'Jeffrey Burchfield': 270381,
#  'Betty Roy': 270380,
#  'Jason Quinones': 270379,
#  'Gary Taylor': 270378,
#  'Jerry Krauss': 270377,
#  'Michael Muffley': 270376,
#  'Edwin Bateman': 270375,
#  'Ruth Smart': 270374,
#  'Christopher Jones': 270373,
#  'Josette Elmore': 270372,
#  'Brittany Boschert': 270371,
#  'Siu Scruggs': 270370,
#  'Anne Leighton': 270369,
#  'Adrienne Silva': 270368,
#  'George White': 270367,
#  'Robert Fonseca': 270366,
#  'Frank Miller': 270365}

# %% [markdown]
# Guardamos el mapeo de nombres de usuario a identificador en el fichero externo "nameIDTable.pkl"

# %%
fileTable = open("nameIDTable.pkl", "wb")
pickle.dump(nameIDTable, fileTable)
fileTable.close()
